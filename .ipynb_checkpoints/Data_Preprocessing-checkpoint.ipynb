# %%
import pandas as pd
import numpy as np

# %%
stats = pd.read_csv("./data/names-cleaned-stats.csv")

# %%
agg_stats = pd.read_csv("./data/sum_agg_stats.csv")

# %%
full_agg_stats = pd.read_csv("./data/agg_stats.csv")

# %%
stats.position.unique()
# Out:
# array(['All Rounder', 'Batsman', 'Bowler', 'Wicket Keeper',
#        'Wicket-Keeper', 'Wicket keeper'], dtype=object)

# %%
position_dict = {"All Rounder": "AR", "Batsman": "BAT", "Bowler": "BWL", "Wicket Keeper": "WK", "Wicket-Keeper": "WK", "Wicket keeper": "WK"}
stats.replace(dict(position=position_dict), inplace=True)

# %% [markdown]
# ### Merging position to full agg stats

# %%
position = stats[["player_name", "position"]].drop_duplicates(subset=["player_name"])

# %%
full_agg_stats_merged = pd.merge(full_agg_stats, position, right_on="player_name", left_on="PLAYER", how="inner")

# %% [markdown]
# ### FULL AGG STATS contains stats for players in the auction and not the whole of IPL history

# %%
full_agg_stats_merged.head()
# Out:
#                  PLAYER  Pts_sum    Pts_mean  years_played  Mat_sum  \
# 0          ABdeVilliers   1712.5  155.681818            11      139
# 1            AaronFinch    751.0   83.444444             9       75
# 2  AbhishekJhunjhunwala    120.5   40.166667             3       21
# 3         AbhishekNayar    340.5   48.642857             7       60
# 4         AdamGilchrist   1091.5  181.916667             6       80
#
#     Mat_mean  Wkts_sum  Wkts_mean  Dots_sum  Dots_mean  4s_sum    4s_mean  \
# 0  12.636364         0   0.000000         0   0.000000     318  28.909091
# 1   8.333333         1   0.111111        13   1.444444     176  19.555556
# 2   7.000000         1   0.333333        27   9.000000      19   6.333333
# 3   8.571429         9   1.285714        69   9.857143      55   7.857143
# 4  13.333333         1   0.166667         1   0.166667     239  39.833333
#
#    6s_sum    6s_mean  Catches_sum  Catches_mean  Stumpings_sum  \
# 0     200  18.181818           80      7.272727              7
# 1      67   7.444444           24      2.666667              0
# 2       5   1.666667           10      3.333333              0
# 3      20   2.857143           13      1.857143              0
# 4      92  15.333333           51      8.500000             16
#
#    Stumpings_mean           player_name position
# 0        0.636364          ABdeVilliers      BAT
# 1        0.000000            AaronFinch      BAT
# 2        0.000000  AbhishekJhunjhunwala      BAT
# 3        0.000000         AbhishekNayar      BAT
# 4        2.666667         AdamGilchrist       WK

# %%
stats.head()
# Out:
#    year_position  player_name  year_points  matches  num_wkts  num_dots  \
# 0              1  ShaneWatson        406.5       15        17       158
# 1             30  ShaneWatson        166.0        6         6        61
# 2              5  ShaneWatson        246.0       11         6        78
# 3             23  ShaneWatson        202.0        7         6        62
# 4              1  ShaneWatson        386.0       16        13       101
#
#    num_fours  num_six  num_catches  num_stumpings team_name  \
# 0         47       19            2              0        RR
# 1         18        9            3              0        RR
# 2         31       17            4              0        RR
# 3         26       14            2              0        RR
# 4         59       22            6              0        RR
#
#   overseas_or_indian  ipl_year position
# 0           Overseas      2008       AR
# 1           Overseas      2010       AR
# 2           Overseas      2011       AR
# 3           Overseas      2012       AR
# 4           Overseas      2013       AR

# %%
def assign_rating_for_season(player_record):
    '''
    For each season the players position in the standings would be considered and depending on their position, 
    their respective stats would be considered and ratings would be summed up.
    
    
    '''
